# %% [markdown]
# ### IMPORT PACKAGE

# %%
# import packages pandas and numpy
import pandas as pd
import numpy as np
import re
# Out:
# C:\Users\Joseph Antonio\AppData\Local\Temp\ipykernel_11388\1639688769.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ### EXTRACT DATA

# %%
# function to extract excel file as dataframe
def extract(file_path, sheet, rows, ind_col):
    
    # read the file into memory
    data = pd.read_excel(file_path, sheet_name = sheet, nrows = rows, index_col = ind_col)

    # excel to df
    data = pd.DataFrame(data)
    
    # printing details about the file
    print(f"data store in [{file_path}]:")
    print(f"\nNumber of rows [{data.shape[0]}], and Number of columns [{data.shape[1]}] in dataframe")
    print(f"\nColumns in dataframe with it's data types: ")
    
    # print data types
    print(data.dtypes)
    
    print(f"\n Printing the count value of NULL per column\n")
    print(data.isna().sum())
    
    # print message before returning the dataframe
    print(f"\nTo view the dataframe extracted from {file_path}, display the value returned by this function!\n\n") 
    
    return data

# %%
# call the function
psgc = extract("datasets\\PSGC-4Q-2023-Publication-Datafile.xlsx",
               sheet = 3,
               rows = None,
               ind_col = None )
# Out:
# data store in [datasets\PSGC-4Q-2023-Publication-Datafile.xlsx]:
#
# Number of rows [43762], and Number of columns [13] in dataframe
#
# Columns in dataframe with it's data types:
# 10-digit PSGC                         float64
# Name                                   object
# Correspondence Code                   float64
# Geographic Level                       object
# Old names                              object
# City Class                             object
# Income\nClassification                 object
# Urban / Rural\n(based on 2020 CPH)     object
# 2015 Population                        object
# Unnamed: 9                             object
# 2020 Population                        object
# Unnamed: 11                            object
# Status                                 object
# dtype: object
#
#  Printing the count value of NULL per column
#
# 10-digit PSGC                             4
# Name                                      0
# Correspondence Code                      38
# Geographic Level                          2
# Old names                             42069
# City Class                            43613
# Income\nClassification                42046
# Urban / Rural\n(based on 2020 CPH)     1761
# 2015 Population                          13
# Unnamed: 9                            43717
# 2020 Population                          13
# Unnamed: 11                           43726
# Status                                40907
# dtype: int64
#
# To view the dataframe extracted from datasets\PSGC-4Q-2023-Publication-Datafile.xlsx, display the value returned by this function!

# %% [markdown]
# ### TRANSFORMING DATA

# %%
# renaming and cleaning the columns/headers 
def transform(data):

    # prints original column names:
    print(f"original columns: {data.columns}\n")
    
    # changing columns/headers string to lowercase, replacing special characters to spaces
    clean_columns = data.columns.str.lower().str.replace(r'[\W\n/()-]|:', '', regex=True)
    
    # passing function as clean_columns to dataframe columns
    data.columns = clean_columns
    
    # return to function
    return data

# %%
# Transformation
psgc = transform(psgc)
# Out:
# original columns: Index(['10digitpsgc', 'name', 'correspondencecode', 'geographiclevel',
#        'oldnames', 'cityclass', 'incomeclassification',
#        'urbanruralbasedon2020cph', '2015population', 'unnamed9',
#        '2020population', 'unnamed11', 'status'],
#       dtype='object')

# %%
def filter_cols(data, column_name, level):
    
    if column_name not in data.columns:
        print(f"Column '{column_name}' not found in DataFrame.")
        return None
    
    data = data[data[column_name] == level][['10digitpsgc', 'name', 'correspondencecode', 'geographiclevel',
       'oldnames', 'cityclass', 'incomeclassification',
       'urbanruralbasedon2020cph', '2015population',
       '2020population','status']]
    
    return data

# %%
columns = psgc.columns

columns
# Out:
# Index(['10digitpsgc', 'name', 'correspondencecode', 'geographiclevel',
#        'oldnames', 'cityclass', 'incomeclassification',
#        'urbanruralbasedon2020cph', '2015population', 'unnamed9',
#        '2020population', 'unnamed11', 'status'],
#       dtype='object')

# %%
# Records per Regional
regional = filter_cols(psgc, 'geographiclevel', "Reg")

# Regional Output
regional
# Out:
#         10digitpsgc                                               name  \
# 0      1.000000e+08                           Region I (Ilocos Region)
# 3397   2.000000e+08                         Region II (Cagayan Valley)
# 5807   3.000000e+08                         Region III (Central Luzon)
# 9050   4.000000e+08                           Region IV-A (CALABARZON)
# 13191  1.700000e+09                                    MIMAROPA Region
# 14730  5.000000e+08                            Region V (Bicol Region)
# 18322  6.000000e+08                        Region VI (Western Visayas)
# 22513  7.000000e+08                       Region VII (Central Visayas)
# 25653  8.000000e+08                      Region VIII (Eastern Visayas)
# 30168  9.000000e+08                    Region IX (Zamboanga Peninsula)
# 32149  1.000000e+09                       Region X (Northern Mindanao)
# 34270  1.100000e+09                           Region XI (Davao Region)
# 35487  1.200000e+09                          Region XII (SOCCSKSARGEN)
# 36637  1.300000e+09                      National Capital Region (NCR)
# 38383  1.400000e+09             Cordillera Administrative Region (CAR)
# 39645  1.600000e+09                               Region XIII (Caraga)
# 41035  1.900000e+09  Bangsamoro Autonomous Region In Muslim Mindana...
#
#        correspondencecode geographiclevel oldnames cityclass  \
# 0              10000000.0             Reg      NaN       NaN
# 3397           20000000.0             Reg      NaN       NaN
# 5807           30000000.0             Reg      NaN       NaN
# 9050           40000000.0             Reg      NaN       NaN
# 13191         170000000.0             Reg      NaN       NaN
# 14730          50000000.0             Reg      NaN       NaN
# 18322          60000000.0             Reg      NaN       NaN
# 22513          70000000.0             Reg      NaN       NaN
# 25653          80000000.0             Reg      NaN       NaN
# 30168          90000000.0             Reg      NaN       NaN
# 32149         100000000.0             Reg      NaN       NaN
# 34270         110000000.0             Reg      NaN       NaN
# 35487         120000000.0             Reg      NaN       NaN
# 36637         130000000.0             Reg      NaN       NaN
# 38383         140000000.0             Reg      NaN       NaN
# 39645         160000000.0             Reg      NaN       NaN
# 41035         150000000.0             Reg      NaN       NaN
#
#       incomeclassification urbanruralbasedon2020cph 2015population  \
# 0                      NaN                      NaN        5026128
# 3397                   NaN                      NaN        3451410
# 5807                   NaN                      NaN       11218177
# 9050                   NaN                      NaN       14414774
# 13191                  NaN                      NaN        2963360
# 14730                  NaN                      NaN        5796989
# 18322                  NaN                      NaN        7536383
# 22513                  NaN                      NaN        7396898
# 25653                  NaN                      NaN        4440150
# 30168                  NaN                      NaN        3629783
# 32149                  NaN                      NaN        4689302
# 34270                  NaN                      NaN        4893318
# 35487                  NaN                      NaN        4545276
# 36637                  NaN                      NaN       12877253
# 38383                  NaN                      NaN        1722006
# 39645                  NaN                      NaN        2596709
# 41035                  NaN                      NaN        3781387
#
#       2020population status
# 0            5301139    NaN
# 3397         3685744    NaN
# 5807        12422172    NaN
# 9050        16195042    NaN
# 13191        3228558    NaN
# 14730        6082165    NaN
# 18322        7954723    NaN
# 22513        8081988    NaN
# 25653        4547150    NaN
# 30168        3875576    NaN
# 32149        5022768    NaN
# 34270        5243536    NaN
# 35487        4901486    NaN
# 36637       13484462    NaN
# 38383        1797660    NaN
# 39645        2804788    NaN
# 41035        4404288    NaN

# %%
# Records per Regional
provincial = filter_cols(psgc, 'geographiclevel', "Prov")

# Provincial Output
provincial
# Out:
#         10digitpsgc                   name  correspondencecode  \
# 1      1.028000e+08           Ilocos Norte          12800000.0
# 584    1.029000e+08             Ilocos Sur          12900000.0
# 1387   1.033000e+08               La Union          13300000.0
# 1984   1.055000e+08             Pangasinan          15500000.0
# 3398   2.009000e+08                Batanes          20900000.0
# ...             ...                    ...                 ...
# 41259  1.903600e+09          Lanao del Sur         153600000.0
# 42461  1.906600e+09                   Sulu         156600000.0
# 42891  1.907000e+09              Tawi-Tawi         157000000.0
# 43106  1.908700e+09  Maguindanao del Norte                 NaN
# 43378  1.908800e+09    Maguindanao del Sur                 NaN
#
#       geographiclevel oldnames cityclass incomeclassification  \
# 1                Prov      NaN       NaN                  1st
# 584              Prov      NaN       NaN                  1st
# 1387             Prov      NaN       NaN                  1st
# 1984             Prov      NaN       NaN                  1st
# 3398             Prov      NaN       NaN                  5th
# ...               ...      ...       ...                  ...
# 41259            Prov      NaN       NaN                  1st
# 42461            Prov      NaN       NaN                  2nd
# 42891            Prov      NaN       NaN                  3rd
# 43106            Prov      NaN       NaN                  1st
# 43378            Prov      NaN       NaN                  1st
#
#       urbanruralbasedon2020cph                     2015population  \
# 1                          NaN                             593081
# 584                        NaN                             689668
# 1387                       NaN                             786653
# 1984                       NaN                            2956726
# 3398                       NaN                              17246
# ...                        ...                                ...
# 41259                      NaN                            1045429
# 42461                      NaN                             824731
# 42891                      NaN                             390715
# 43106                      NaN  (excluding COTOBATO CITY) 536,900
# 43378                      NaN                             637033
#
#                           2020population status
# 1                                 609588    NaN
# 584                               706009    NaN
# 1387                              822352    NaN
# 1984                             3163190    NaN
# 3398                               18831    NaN
# ...                                  ...    ...
# 41259                            1195518    NaN
# 42461                            1000108    NaN
# 42891                             440276    NaN
# 43106  (excluding COTOBATO CITY) 618,421    NaN
# 43378                             723758    NaN
#
# [82 rows x 11 columns]

# %%
# Records per Municipal
municipal = filter_cols(psgc, 'geographiclevel', "Mun")

# Municipal Output
municipal
# Out:
#         10digitpsgc                      name  correspondencecode  \
# 2      1.028010e+08                     Adams          12801000.0
# 4      1.028020e+08                   Bacarra          12802000.0
# 48     1.028030e+08                     Badoc          12803000.0
# 80     1.028040e+08                    Bangui          12804000.0
# 139    1.028060e+08                    Burgos          12806000.0
# ...             ...                       ...                 ...
# 43618  1.908820e+09             Shariff Aguak         153808000.0
# 43632  1.908821e+09  Shariff Saydona Mustapha         153837000.0
# 43649  1.908822e+09                 South Upi         153817000.0
# 43661  1.908823e+09        Sultan Sa Barongis         153813000.0
# 43674  1.908824e+09                   Talayan         153816000.0
#
#       geographiclevel   oldnames cityclass incomeclassification  \
# 2                 Mun        NaN       NaN                  5th
# 4                 Mun        NaN       NaN                  3rd
# 48                Mun        NaN       NaN                  3rd
# 80                Mun        NaN       NaN                  4th
# 139               Mun        NaN       NaN                  5th
# ...               ...        ...       ...                  ...
# 43618             Mun    Maganoy       NaN                  2nd
# 43632             Mun        NaN       NaN                    -
# 43649             Mun        NaN       NaN                 4th*
# 43661             Mun  Lambayong       NaN                  2nd
# 43674             Mun        NaN       NaN                 4th*
#
#       urbanruralbasedon2020cph 2015population 2020population status
# 2                          NaN           1792           2189    NaN
# 4                          NaN          32215          33496    NaN
# 48                         NaN          31616          32530    NaN
# 80                         NaN          14672          15019    NaN
# 139                        NaN           9777          10759    NaN
# ...                        ...            ...            ...    ...
# 43618                      NaN          31692          33982    NaN
# 43632                      NaN          19855          25080    NaN
# 43649                      NaN          40178          43197    NaN
# 43661                      NaN          22425          24476    NaN
# 43674                      NaN          30032          34156    NaN
#
# [1485 rows x 11 columns]

# %%
# Records per City
city = filter_cols(psgc, 'geographiclevel', "City")

# City Output
city
# Out:
#         10digitpsgc                   name  correspondencecode  \
# 95     1.028050e+08          City of Batac          12805000.0
# 237    1.028120e+08         City of Laoag           12812000.0
# 706    1.029060e+08         City of Candon          12906000.0
# 1347   1.029340e+08         City of Vigan           12934000.0
# 1792   1.033140e+08  City of San Fernando           13314000.0
# ...             ...                    ...                 ...
# 40629  1.606803e+09         City of Bislig         166803000.0
# 40905  1.606819e+09        City of Tandag          166819000.0
# 41037  1.900702e+09       City of Lamitan          150702000.0
# 41736  1.903617e+09        City of Marawi          153617000.0
# 43138  1.908703e+09       City of Cotabato         129804000.0
#
#       geographiclevel oldnames cityclass incomeclassification  \
# 95               City      NaN        CC                  5th
# 237              City      NaN        CC                  3rd
# 706              City      NaN        CC                  4th
# 1347             City      NaN        CC                  4th
# 1792             City      NaN        CC                  3rd
# ...               ...      ...       ...                  ...
# 40629            City      NaN        CC                  3rd
# 40905            City      NaN        CC                  5th
# 41037            City      NaN        CC                  6th
# 41736            City      NaN        CC                  4th
# 43138            City      NaN       ICC                  3rd
#
#       urbanruralbasedon2020cph 2015population 2020population   status
# 95                         NaN          55201          55484      NaN
# 237                        NaN         111125         111651  Capital
# 706                        NaN          60623          61432      NaN
# 1347                       NaN          53879          53935  Capital
# 1792                       NaN         121812         125640  Capital
# ...                        ...            ...            ...      ...
# 40629                      NaN          94535          99290      NaN
# 40905                      NaN          56364          62669  Capital
# 41037                      NaN          74782         100150  Capital
# 41736                      NaN         201785         207010  Capital
# 43138                      NaN         299438         325079      NaN
#
# [149 rows x 11 columns]

# %%
# Records per Baranggay
baranggay = filter_cols(psgc, 'geographiclevel', "Bgy")

# Count Records of Baranggay
print(f"Baranggay counts are: {baranggay.shape[0]}\n")

# Count based on urbanruralbasedon2020cph
brgy_ur_count = baranggay.groupby(['urbanruralbasedon2020cph'])['urbanruralbasedon2020cph'].count()
print("Count of Urban/ Rural/ Null:")
print(f"{brgy_ur_count.to_string(header=False)}\n")


# Baranggay Output
baranggay
# Out:
# Baranggay counts are: 42001
#
# Count of Urban/ Rural/ Null:
# -       27
# R    34054
# U     7920
#         10digitpsgc        name  correspondencecode geographiclevel oldnames  \
# 3      1.028010e+08       Adams          12801001.0             Bgy      NaN
# 5      1.028020e+08        Bani          12802001.0             Bgy      NaN
# 6      1.028020e+08       Buyon          12802002.0             Bgy      NaN
# 7      1.028020e+08    Cabaruan          12802003.0             Bgy      NaN
# 8      1.028020e+08  Cabulalaan          12802004.0             Bgy      NaN
# ...             ...         ...                 ...             ...      ...
# 43757  1.999908e+09     Lagunde         124712030.0             Bgy      NaN
# 43758  1.999908e+09  Macasendeg         124712035.0             Bgy      NaN
# 43759  1.999908e+09  Manaulanan         124712037.0             Bgy      NaN
# 43760  1.999908e+09    Pamalian         124712062.0             Bgy      NaN
# 43761  1.999908e+09     Tapodoc         124717017.0             Bgy      NaN
#
#       cityclass incomeclassification urbanruralbasedon2020cph 2015population  \
# 3           NaN                  NaN                        R           1792
# 5           NaN                  NaN                        R            853
# 6           NaN                  NaN                        R           1596
# 7           NaN                  NaN                        R           1413
# 8           NaN                  NaN                        R            733
# ...         ...                  ...                      ...            ...
# 43757       NaN                  NaN                        U           3701
# 43758       NaN                  NaN                        R           3775
# 43759       NaN                  NaN                        U           7477
# 43760       NaN                  NaN                        R           2982
# 43761       NaN                  NaN                        R           2255
#
#       2020population status
# 3               2189   Pob.
# 5               1079    NaN
# 6               1669    NaN
# 7               1418    NaN
# 8                733    NaN
# ...              ...    ...
# 43757           5332    NaN
# 43758           2516    NaN
# 43759           7632    NaN
# 43760           3256    NaN
# 43761           1767    NaN
#
# [42001 rows x 11 columns]

# %%
# Records per NCR Districts
ncr_districts = filter_cols(psgc, 'geographiclevel', "Dist")

# Count of Districts NCR
print(f"NCR Disctricts counts are: {ncr_districts.shape[0]}\n")

# NCR Districts Output
ncr_districts
# Out:
# NCR Disctricts counts are: 4
#        10digitpsgc                                               name  \
# 36638          NaN  NCR, City of Manila, First District (Not a Pro...
# 37551          NaN              NCR, Second District (Not a Province)
# 37793          NaN               NCR, Third District (Not a Province)
# 38058          NaN              NCR, Fourth District (Not a Province)
#
#        correspondencecode geographiclevel oldnames cityclass  \
# 36638         133900000.0            Dist      NaN       NaN
# 37551         137400000.0            Dist      NaN       NaN
# 37793         137500000.0            Dist      NaN       NaN
# 38058         137600000.0            Dist      NaN       NaN
#
#       incomeclassification urbanruralbasedon2020cph 2015population  \
# 36638                  NaN                      NaN        1780148
# 37551                  NaN                      NaN        4650613
# 37793                  NaN                      NaN        2819388
# 38058                  NaN                      NaN        3627104
#
#       2020population status
# 36638        1846513    NaN
# 37551        4771371    NaN
# 37793        3004627    NaN
# 38058        3861951    NaN

# %%
def info_details(source):
    
    data = source
    print(f"There are {data.shape[0]} records\n")
    
    ur_count = data.groupby(['urbanruralbasedon2020cph'])['urbanruralbasedon2020cph'].count()
    print("Count of Urban/Rural based on 2020 CPH:")
    print(f"{ur_count.to_string(index=True, header=False)}\n")
    
    status_count = data.groupby(['status'])['status'].count()
    print("Count of Status:")
    print(f"{status_count.to_string(index=True, header=False)}\n")
    
    class_count = data.groupby(['incomeclassification'])['incomeclassification'].count()
    print("Count of Income Classification:")
    print(f"{class_count.to_string(index=True, header=False)}\n")     
    
    return data

# %%
# Urban Baranggay Based on 2020 CPH
urban = filter_cols(psgc, 'urbanruralbasedon2020cph', "U")

# Display rural dataframe
urban
# Out:
#         10digitpsgc          name  correspondencecode geographiclevel  \
# 60     1.028030e+08      Garreta           12803013.0             Bgy
# 106    1.028050e+08    Callaguip           12805012.0             Bgy
# 111    1.028050e+08     Caunayan           12805017.0             Bgy
# 118    1.028050e+08        Lacub           12805024.0             Bgy
# 124    1.028050e+08  Ricarte Pob.          12805030.0             Bgy
# ...             ...           ...                 ...             ...
# 43742  1.999906e+09       Nunguan         124712044.0             Bgy
# 43748  1.999907e+09         Bulol         124712012.0             Bgy
# 43750  1.999907e+09     Kabasalan         124712024.0             Bgy
# 43757  1.999908e+09       Lagunde         124712030.0             Bgy
# 43759  1.999908e+09    Manaulanan         124712037.0             Bgy
#
#       oldnames cityclass incomeclassification urbanruralbasedon2020cph  \
# 60         NaN       NaN                  NaN                        U
# 106        NaN       NaN                  NaN                        U
# 111        NaN       NaN                  NaN                        U
# 118        NaN       NaN                  NaN                        U
# 124    Nalasin       NaN                  NaN                        U
# ...        ...       ...                  ...                      ...
# 43742      NaN       NaN                  NaN                        U
# 43748      NaN       NaN                  NaN                        U
# 43750      NaN       NaN                  NaN                        U
# 43757      NaN       NaN                  NaN                        U
# 43759      NaN       NaN                  NaN                        U
#
#       2015population 2020population status
# 60              1376           1383   Pob.
# 106              900            832   Pob.
# 111             1175           1105   Pob.
# 118              502            422   Pob.
# 124              818            765    NaN
# ...              ...            ...    ...
# 43742           4569           5380    NaN
# 43748           4203           5145    NaN
# 43750           5769           7591    NaN
# 43757           3701           5332    NaN
# 43759           7477           7632    NaN
#
# [7920 rows x 11 columns]

# %%
# Rural Baranggay Based on 2020 CPH
rural = filter_cols(psgc, 'urbanruralbasedon2020cph', "R")

# Display rural dataframe
rural
# Out:
#         10digitpsgc        name  correspondencecode geographiclevel oldnames  \
# 3      1.028010e+08       Adams          12801001.0             Bgy      NaN
# 5      1.028020e+08        Bani          12802001.0             Bgy      NaN
# 6      1.028020e+08       Buyon          12802002.0             Bgy      NaN
# 7      1.028020e+08    Cabaruan          12802003.0             Bgy      NaN
# 8      1.028020e+08  Cabulalaan          12802004.0             Bgy      NaN
# ...             ...         ...                 ...             ...      ...
# 43755  1.999908e+09      Bualan         124712009.0             Bgy      NaN
# 43756  1.999908e+09     Dunguan         124717004.0             Bgy      NaN
# 43758  1.999908e+09  Macasendeg         124712035.0             Bgy      NaN
# 43760  1.999908e+09    Pamalian         124712062.0             Bgy      NaN
# 43761  1.999908e+09     Tapodoc         124717017.0             Bgy      NaN
#
#       cityclass incomeclassification urbanruralbasedon2020cph 2015population  \
# 3           NaN                  NaN                        R           1792
# 5           NaN                  NaN                        R            853
# 6           NaN                  NaN                        R           1596
# 7           NaN                  NaN                        R           1413
# 8           NaN                  NaN                        R            733
# ...         ...                  ...                      ...            ...
# 43755       NaN                  NaN                        R           2176
# 43756       NaN                  NaN                        R           2805
# 43758       NaN                  NaN                        R           3775
# 43760       NaN                  NaN                        R           2982
# 43761       NaN                  NaN                        R           2255
#
#       2020population status
# 3               2189   Pob.
# 5               1079    NaN
# 6               1669    NaN
# 7               1418    NaN
# 8                733    NaN
# ...              ...    ...
# 43755           2177    NaN
# 43756           3285    NaN
# 43758           2516    NaN
# 43760           3256    NaN
# 43761           1767    NaN
#
# [34054 rows x 11 columns]

# %%
# CC (Components Cities) based on City Class
cc = filter_cols(psgc, 'cityclass', 'CC')

# NCR Districts Output
cc
# Out:
#         10digitpsgc                   name  correspondencecode  \
# 95     1.028050e+08          City of Batac          12805000.0
# 237    1.028120e+08         City of Laoag           12812000.0
# 706    1.029060e+08         City of Candon          12906000.0
# 1347   1.029340e+08         City of Vigan           12934000.0
# 1792   1.033140e+08  City of San Fernando           13314000.0
# ...             ...                    ...                 ...
# 40518  1.606724e+09       City of Surigao          166724000.0
# 40629  1.606803e+09         City of Bislig         166803000.0
# 40905  1.606819e+09        City of Tandag          166819000.0
# 41037  1.900702e+09       City of Lamitan          150702000.0
# 41736  1.903617e+09        City of Marawi          153617000.0
#
#       geographiclevel oldnames cityclass incomeclassification  \
# 95               City      NaN        CC                  5th
# 237              City      NaN        CC                  3rd
# 706              City      NaN        CC                  4th
# 1347             City      NaN        CC                  4th
# 1792             City      NaN        CC                  3rd
# ...               ...      ...       ...                  ...
# 40518            City      NaN        CC                  3rd
# 40629            City      NaN        CC                  3rd
# 40905            City      NaN        CC                  5th
# 41037            City      NaN        CC                  6th
# 41736            City      NaN        CC                  4th
#
#       urbanruralbasedon2020cph 2015population 2020population   status
# 95                         NaN          55201          55484      NaN
# 237                        NaN         111125         111651  Capital
# 706                        NaN          60623          61432      NaN
# 1347                       NaN          53879          53935  Capital
# 1792                       NaN         121812         125640  Capital
# ...                        ...            ...            ...      ...
# 40518                      NaN         154137         171107  Capital
# 40629                      NaN          94535          99290      NaN
# 40905                      NaN          56364          62669  Capital
# 41037                      NaN          74782         100150  Capital
# 41736                      NaN         201785         207010  Capital
#
# [111 rows x 11 columns]

# %%
# ICC (Independent Components Cities) based on City Class
icc = filter_cols(psgc, 'cityclass', 'ICC')

# ICC
icc
# Out:
#         10digitpsgc              name  correspondencecode geographiclevel  \
# 2438   1.055180e+08   City of Dagupan          15518000.0            City
# 5264   2.031350e+08  City of Santiago          23135000.0            City
# 16477  5.017240e+08      City of Naga          51724000.0            City
# 27385  8.037380e+08        Ormoc City          83738000.0            City
# 43138  1.908703e+09  City of Cotabato         129804000.0            City
#
#       oldnames cityclass incomeclassification urbanruralbasedon2020cph  \
# 2438       NaN       ICC                  2nd                      NaN
# 5264       NaN       ICC                  1st                      NaN
# 16477      NaN       ICC                  2nd                      NaN
# 27385      NaN       ICC                  1st                      NaN
# 43138      NaN       ICC                  3rd                      NaN
#
#       2015population 2020population status
# 2438          171271         174302    NaN
# 5264          134830         148580    NaN
# 16477         196003         209170    NaN
# 27385         215031         230998    NaN
# 43138         299438         325079    NaN

# %%
# HUC (Highly Urbanized Cities) based on City Class
# Population: Minimum 200,000
# Annual Income: Php. 50M
huc = filter_cols(psgc, 'cityclass', 'HUC')

# HUC
huc
# Out:
#         10digitpsgc                      name  correspondencecode  \
# 7538   3.301000e+08           City of Angeles          35401000.0
# 8745   3.314000e+08          City of Olongapo          37107000.0
# 12339  4.312000e+08           City of Lucena           45624000.0
# 14297  1.731500e+09  City of Puerto Princesa          175316000.0
# 20474  6.310000e+08           City of Iloilo           63022000.0
# 21715  6.302000e+08          City of Bacolod           64501000.0
# 24041  7.306000e+08             City of Cebu           72217000.0
# 24327  7.311000e+08         City of Lapu-Lapu          72226000.0
# 24403  7.313000e+08           City of Mandaue          72230000.0
# 27680  8.316000e+08         City of Tacloban           83747000.0
# 31480  9.317000e+08         City of Zamboanga          97332000.0
# 32765  1.030900e+09            City of Iligan         103504000.0
# 33807  1.030500e+09   City of Cagayan De Oro          104305000.0
# 34533  1.130700e+09             City of Davao         112402000.0
# 36011  1.230800e+09    City of General Santos         126303000.0
# 36639  1.380600e+09            City of Manila         133900000.0
# 37552  1.380500e+09       City of Mandaluyong         137401000.0
# 37580  1.380700e+09          City of Marikina         137402000.0
# 37597  1.381200e+09             City of Pasig         137403000.0
# 37628  1.381300e+09               Quezon City         137404000.0
# 37771  1.381400e+09          City of San Juan         137405000.0
# 37794  1.380100e+09          City of Caloocan         137501000.0
# 37983  1.380400e+09           City of Malabon         137502000.0
# 38005  1.380900e+09           City of Navotas         137503000.0
# 38024  1.381600e+09        City of Valenzuela         137504000.0
# 38059  1.380200e+09         City of Las Piñas         137601000.0
# 38080  1.380300e+09            City of Makati         137602000.0
# 38104  1.380800e+09        City of Muntinlupa         137603000.0
# 38114  1.381000e+09         City of Parañaque         137604000.0
# 38131  1.381100e+09                Pasay City         137605000.0
# 38344  1.381500e+09            City of Taguig         137607000.0
# 38725  1.430300e+09            City of Baguio         141102000.0
# 39673  1.630400e+09           City of Butuan          160202000.0
#
#       geographiclevel   oldnames cityclass incomeclassification  \
# 7538             City        NaN       HUC                  1st
# 8745             City        NaN       HUC                  1st
# 12339            City        NaN       HUC                  2nd
# 14297            City        NaN       HUC                  1st
# 20474            City        NaN       HUC                  1st
# 21715            City        NaN       HUC                  1st
# 24041            City        NaN       HUC                  1st
# 24327            City       Opon       HUC                  1st
# 24403            City        NaN       HUC                  1st
# 27680            City        NaN       HUC                  1st
# 31480            City        NaN       HUC                  1st
# 32765            City        NaN       HUC  1st* (reclass 2005)
# 33807            City        NaN       HUC                  1st
# 34533            City        NaN       HUC                  1st
# 36011            City  Dadiangas       HUC                  1st
# 36639            City        NaN       HUC              Special
# 37552            City        NaN       HUC                  1st
# 37580            City        NaN       HUC                  1st
# 37597            City        NaN       HUC                  1st
# 37628            City        NaN       HUC              Special
# 37771            City        NaN       HUC                  1st
# 37794            City        NaN       HUC                  1st
# 37983            City        NaN       HUC                  1st
# 38005            City        NaN       HUC                  2nd
# 38024            City        NaN       HUC                  1st
# 38059            City        NaN       HUC                  1st
# 38080            City        NaN       HUC                  1st
# 38104            City        NaN       HUC                  1st
# 38114            City        NaN       HUC                  1st
# 38131            City        NaN       HUC                  1st
# 38344            City        NaN       HUC                  1st
# 38725            City        NaN       HUC                  1st
# 39673            City        NaN       HUC                  1st
#
#       urbanruralbasedon2020cph 2015population 2020population   status
# 7538                       NaN         411634         462928      NaN
# 8745                       NaN         233040         260317      NaN
# 12339                      NaN         266248         278924  Capital
# 14297                      NaN         255116         307079  Capital
# 20474                      NaN         447992         457626  Capital
# 21715                      NaN         561875         600783  Capital
# 24041                      NaN         922611         964169  Capital
# 24327                      NaN         408112         497604      NaN
# 24403                      NaN         362654         364116      NaN
# 27680                      NaN         242089         251881  Capital
# 31480                      NaN         861799         977234      NaN
# 32765                      NaN         342618         363115      NaN
# 33807                      NaN         675950         728402  Capital
# 34533                      NaN        1632991        1776949      NaN
# 36011                      NaN         594446         697315      NaN
# 36639                      NaN        1780148        1846513      NaN
# 37552                      NaN         386276         425758      NaN
# 37580                      NaN         450741         456059      NaN
# 37597                      NaN         755300         803159      NaN
# 37628                      NaN        2936116        2960048      NaN
# 37771                      NaN         122180         126347      NaN
# 37794                      NaN        1583978        1661584      NaN
# 37983                      NaN         365525         380522      NaN
# 38005                      NaN         249463         247543      NaN
# 38024                      NaN         620422         714978      NaN
# 38059                      NaN         588894         606293      NaN
# 38080                      NaN         582602         629616      NaN
# 38104                      NaN         504509         543445      NaN
# 38114                      NaN         665822         689992      NaN
# 38131                      NaN         416522         440656      NaN
# 38344                      NaN         804915         886722      NaN
# 38725                      NaN         345366         366358      NaN
# 39673                      NaN         337063         372910  Capital

# %%
brgy_details = info_details(baranggay)

brgy_details
# Out:
# There are 42001 records
#
# Count of Urban/Rural based on 2020 CPH:
# -       27
# R    34054
# U     7920
#
# Count of Status:
# Pob.    2773
#
# Count of Income Classification:
# Series([], )
#         10digitpsgc        name  correspondencecode geographiclevel oldnames  \
# 3      1.028010e+08       Adams          12801001.0             Bgy      NaN
# 5      1.028020e+08        Bani          12802001.0             Bgy      NaN
# 6      1.028020e+08       Buyon          12802002.0             Bgy      NaN
# 7      1.028020e+08    Cabaruan          12802003.0             Bgy      NaN
# 8      1.028020e+08  Cabulalaan          12802004.0             Bgy      NaN
# ...             ...         ...                 ...             ...      ...
# 43757  1.999908e+09     Lagunde         124712030.0             Bgy      NaN
# 43758  1.999908e+09  Macasendeg         124712035.0             Bgy      NaN
# 43759  1.999908e+09  Manaulanan         124712037.0             Bgy      NaN
# 43760  1.999908e+09    Pamalian         124712062.0             Bgy      NaN
# 43761  1.999908e+09     Tapodoc         124717017.0             Bgy      NaN
#
#       cityclass incomeclassification urbanruralbasedon2020cph 2015population  \
# 3           NaN                  NaN                        R           1792
# 5           NaN                  NaN                        R            853
# 6           NaN                  NaN                        R           1596
# 7           NaN                  NaN                        R           1413
# 8           NaN                  NaN                        R            733
# ...         ...                  ...                      ...            ...
# 43757       NaN                  NaN                        U           3701
# 43758       NaN                  NaN                        R           3775
# 43759       NaN                  NaN                        U           7477
# 43760       NaN                  NaN                        R           2982
# 43761       NaN                  NaN                        R           2255
#
#       2020population status
# 3               2189   Pob.
# 5               1079    NaN
# 6               1669    NaN
# 7               1418    NaN
# 8                733    NaN
# ...              ...    ...
# 43757           5332    NaN
# 43758           2516    NaN
# 43759           7632    NaN
# 43760           3256    NaN
# 43761           1767    NaN
#
# [42001 rows x 11 columns]
